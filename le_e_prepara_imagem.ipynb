# %%
import os

import numpy as np
from skimage.io import imread, imsave, imshow
from scipy.misc import imresize

from PIL import Image, ImageDraw

from sklearn.model_selection import train_test_split

# %%
file_name = 'img_00000'
image = imread(os.path.join('imgs/teste', file_name + '_8' + '.jpg'), as_gray=True)

image2 = np.array(image, dtype=np.uint8)
image2 = image2/255

# %%
image2.shape
# Out:
# (512, 416)

# %%
raws_pt = [x for x in os.listdir(os.path.join('imgs/teste')) if '_8' in x]
masks_pt = [x for x in os.listdir(os.path.join('imgs/teste')) if 'mask' in x]

# %%
im = imread(os.path.join('imgs\\teste',raws_pt[0]))
im = imresize(im,0.4,interp='bicubic',mode='L')*255
im.shape
# Out:
# c:\users\sofia\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# (204, 166)

# %%
Image.fromarray(np.array([np.abs(255 - x) for x in im]),mode="L")
# Out:
# <PIL.Image.Image image mode=L size=166x204 at 0x198F885AA58>

# %% [markdown]
# ### Em batelada:

# %%
raws_pt = [x for x in os.listdir(os.path.join('imgs/teste')) if '_8' in x]
masks_pt = [x for x in os.listdir(os.path.join('imgs/teste')) if 'mask' in x]
train_pt, test_pt = train_test_split([x.replace('_8.jpg','') for x in os.listdir(os.path.join('imgs/teste')) if '_8' in x], test_size=0.1)

proporcao_resize = 0.8

# %%
raws = [imresize(imread(os.path.join('imgs\\teste',x)),proporcao_resize,interp='bicubic',mode='L') for x in raws_pt]
# Out:
# c:\users\sofia\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   """Entry point for launching an IPython kernel.

# %%
masks = [imresize(imread(os.path.join('imgs\\teste',x))[:,:,0],proporcao_resize,interp='bicubic',mode='L') for x in masks_pt]
# Out:
# c:\users\sofia\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   """Entry point for launching an IPython kernel.

# %%
train_images = [imresize(imread(os.path.join('imgs\\teste',x+'_8.jpg')),proporcao_resize,interp='bicubic',mode='L') for x in train_pt]
train_masks = [imresize(imread(os.path.join('imgs\\teste',x+'_mask.jpg'))[:,:,0],proporcao_resize,interp='bicubic',mode='L') for x in train_pt]

test_images = [imresize(imread(os.path.join('imgs\\teste',x+'_8.jpg')),proporcao_resize,interp='bicubic',mode='L') for x in test_pt]
test_masks = [imresize(imread(os.path.join('imgs\\teste',x+'_mask.jpg'))[:,:,0],proporcao_resize,interp='bicubic',mode='L') for x in test_pt]
# Out:
# c:\users\sofia\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   """Entry point for launching an IPython kernel.
# c:\users\sofia\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#
# c:\users\sofia\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   after removing the cwd from sys.path.
# c:\users\sofia\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   """

# %%
[x.split('_')[1] for x in test_pt]
# Out:
# ['00181',
#  '00051',
#  '01605',
#  '00397',
#  '02361',
#  '01749',
#  '00655',
#  '01757',
#  '00225',
#  '02491',
#  '02701',
#  '02142',
#  '02122',
#  '00673',
#  '02160',
#  '01013',
#  '00490',
#  '00849',
#  '02724',
#  '00417',
#  '02333',
#  '02631',
#  '02743',
#  '01527',
#  '01578',
#  '01475',
#  '01942',
#  '02487',
#  '02185',
#  '01588',
#  '02434',
#  '01110',
#  '00956',
#  '02077',
#  '02251',
#  '00679',
#  '00399',
#  '02183',
#  '01933',
#  '00555',
#  '02065',
#  '01814',
#  '01508',
#  '00054',
#  '02188',
#  '02417',
#  '00171',
#  '02467',
#  '00551',
#  '00973',
#  '02718',
#  '01028',
#  '00566',
#  '02456',
#  '01622',
#  '00313',
#  '02041',
#  '00949',
#  '01134',
#  '01436',
#  '02630',
#  '01491',
#  '02347',
#  '01418',
#  '01679',
#  '01016',
#  '00872',
#  '01688',
#  '02689',
#  '01987',
#  '00356',
#  '02279',
#  '02364',
#  '01316',
#  '00070',
#  '02166',
#  '00853',
#  '00596',
#  '02301',
#  '00325',
#  '01044',
#  '00293',
#  '01610',
#  '02345',
#  '00886',
#  '00715',
#  '00870',
#  '01032',
#  '01274',
#  '01092',
#  '00464',
#  '00752',
#  '01441',
#  '00563',
#  '01782',
#  '02288',
#  '00143',
#  '00086',
#  '01619',
#  '02348',
#  '01342',
#  '01168',
#  '02229',
#  '00015',
#  '00365',
#  '02371',
#  '01173',
#  '01616',
#  '01165',
#  '01496',
#  '01522',
#  '02595',
#  '00625',
#  '01556',
#  '01353',
#  '01039',
#  '00233',
#  '00100',
#  '00214',
#  '00497',
#  '01047',
#  '02582',
#  '00359',
#  '01176',
#  '01568',
#  '02079',
#  '01821',
#  '00172',
#  '00126',
#  '00016',
#  '00531',
#  '00617',
#  '02672',
#  '00543',
#  '00923',
#  '01382',
#  '01200',
#  '01414',
#  '02531',
#  '00029',
#  '02782',
#  '02761',
#  '00248',
#  '02278',
#  '01214',
#  '01311',
#  '02087',
#  '02769',
#  '01171',
#  '01332',
#  '00449',
#  '01794',
#  '02528',
#  '01065',
#  '02500',
#  '01101',
#  '01661',
#  '01392',
#  '01977',
#  '02710',
#  '01394',
#  '02170',
#  '02479',
#  '01746',
#  '01670',
#  '02098',
#  '02793',
#  '00713',
#  '01206',
#  '01575',
#  '02450',
#  '00242',
#  '02266',
#  '02678',
#  '02629',
#  '02196',
#  '01457',
#  '00714',
#  '02461',
#  '02146',
#  '00788',
#  '00977',
#  '02006',
#  '01484',
#  '00936',
#  '01201',
#  '00467',
#  '00992',
#  '02318',
#  '02127',
#  '00804',
#  '02322',
#  '00950',
#  '01396',
#  '01425',
#  '02571',
#  '00470',
#  '02362',
#  '00392',
#  '00896',
#  '00201',
#  '01655',
#  '02291',
#  '02711',
#  '00158',
#  '02315',
#  '02100',
#  '01267',
#  '00539',
#  '02209',
#  '00630',
#  '00267',
#  '00295',
#  '00025',
#  '02790',
#  '00004',
#  '01391',
#  '00546',
#  '01514',
#  '01593',
#  '01083',
#  '02518',
#  '02676',
#  '01548',
#  '00026',
#  '02320',
#  '00241',
#  '00362',
#  '01706',
#  '01497',
#  '01109',
#  '02073',
#  '02236',
#  '00257',
#  '00875',
#  '02520',
#  '00614',
#  '01315',
#  '01041',
#  '02090',
#  '01993',
#  '01093',
#  '00784',
#  '01062',
#  '01945',
#  '00576',
#  '00106',
#  '02593',
#  '00443',
#  '02532',
#  '01462',
#  '00331',
#  '01299',
#  '01003',
#  '01259',
#  '00772',
#  '00580',
#  '02705',
#  '00063',
#  '02460',
#  '02367',
#  '00355',
#  '02530',
#  '00790',
#  '01779',
#  '00736',
#  '00024',
#  '00159',
#  '01195',
#  '01852',
#  '00568',
#  '01502',
#  '00890',
#  '00326',
#  '02633',
#  '01149',
#  '00466',
#  '01477',
#  '00232',
#  '01895']

# %%
Image.fromarray(train_images[60],mode="L")
# Out:
# <PIL.Image.Image image mode=L size=332x409 at 0x198F71497B8>

# %%
train_images[60].shape
# Out:
# (409, 332)

# %% [markdown]
# ### Versão produtiva:

# %%
import os

import numpy as np
from skimage.io import imread
from scipy.misc import imresize

from sklearn.model_selection import train_test_split

raws_pt = [x for x in os.listdir(os.path.join('imgs/teste')) if '_8' in x]
masks_pt = [x for x in os.listdir(os.path.join('imgs/teste')) if 'mask' in x]
train_pt, test_pt = train_test_split([x.replace('_8.jpg','') for x in os.listdir(os.path.join('imgs/teste')) if '_8' in x], test_size=0.1)

proporcao = 0.8
file_name = 'img_00000'
image = imread(os.path.join('imgs/teste', file_name + '_8' + '.jpg'), as_gray=True)
proporcao_resize = ((int(np.floor(proporcao*image.shape[0])//16)*16),(int(np.floor(proporcao*image.shape[1])//16)*16))

train_images = [imresize(imread(os.path.join('imgs\\teste',x+'_8.jpg')),proporcao_resize,interp='bicubic',mode='L') for x in train_pt]
train_masks = [imresize(imread(os.path.join('imgs\\teste',x+'_mask.jpg'))[:,:,0],proporcao_resize,interp='bicubic',mode='L') for x in train_pt]

test_images = [imresize(imread(os.path.join('imgs\\teste',x+'_8.jpg')),proporcao_resize,interp='bicubic',mode='L') for x in test_pt]
test_masks = [imresize(imread(os.path.join('imgs\\teste',x+'_mask.jpg'))[:,:,0],proporcao_resize,interp='bicubic',mode='L') for x in test_pt]

test_train_files = os.path.join('test_train_files')
if not os.path.exists(test_train_files):
    os.mkdir(test_train_files)

np.save(os.path.join(test_train_files,'images_train.npy'), train_images)
np.save(os.path.join(test_train_files,'masks_train.npy'), train_masks)
np.save(os.path.join(test_train_files,'images_test.npy'), test_images)
np.save(os.path.join(test_train_files,'masks_test.npy'), test_masks)

np.save(os.path.join(test_train_files,'images16_train.npy'), train_images)
np.save(os.path.join(test_train_files,'images16_test.npy'), test_images)

np.save(os.path.join(test_train_files,'ids_train.npy'), [x.split('_')[1] for x in train_pt])
np.save(os.path.join(test_train_files,'ids_test.npy'), [x.split('_')[1] for x in test_pt])

print("Feito! Imagens com proporção {}".format(proporcao_resize))
# Out:
# c:\users\sofia\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:18: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# c:\users\sofia\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:19: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# c:\users\sofia\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:21: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# c:\users\sofia\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:22: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# Feito! Imagens com proporção (400, 320)
